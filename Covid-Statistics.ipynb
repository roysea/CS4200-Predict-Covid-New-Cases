# %% [markdown]
# # Covid-19 Statistics
# ### Data State by State
# -----------------------------------------------
# by Roya Salei
#
# Course CS4200- Artificial Intelligence
#
# Professor: Dr. Husain Zaidi

# %%
import pandas as pd
df = pd.read_csv("state_ts.csv")
df.iloc[755:760]
# Out:
#            date state  newCases    cases  newDeaths  deaths  positiveTests  \
# 755  2020-07-13    AL    1958.0  55545.0        3.0  1124.0        95803.0
# 756  2020-07-14    AL    1710.0  57255.0       40.0  1164.0        98321.0
# 757  2020-07-15    AL    1812.0  59067.0       47.0  1211.0       101007.0
# 758  2020-07-16    AL    2021.0  61088.0       19.0  1230.0       103821.0
# 759  2020-07-17    AL    2003.0  63091.0       35.0  1265.0       107054.0
#
#      negativeTests  vaccinationsCompleted  hospitalBeds.capacity  \
# 755       670435.0                    NaN                    NaN
# 756       682973.0                    NaN                    NaN
# 757       698252.0                    NaN                    NaN
# 758       710958.0                    NaN                    NaN
# 759       727141.0                    NaN                    NaN
#
#      hospitalBeds.currentUsageTotal  hospitalBeds.currentUsageCovid  \
# ...

# %% [markdown]
# ### Usage:
# Add a new column called epoc

# %%
df["date"]= df["date"].astype("datetime64")

# %%
df = df.set_index('date')

# %% [markdown]
# Check if dates are Timestamp, if not convert them

# %%
# # change state name to integer
# states = df['state'].unique()
# for i in range(len(states)):
#     df['state']=i
# df.tail(10)

# %%
import matplotlib.pyplot as plt
AK = df.loc[df['state']=='AK']
AK
# Out:
#            state  newCases     cases  newDeaths  deaths  positiveTests  \
# date
# 2020-03-01    AK       NaN       NaN        NaN     NaN            NaN
# 2020-03-02    AK       NaN       NaN        NaN     NaN            NaN
# 2020-03-03    AK       NaN       NaN        NaN     NaN            NaN
# 2020-03-04    AK       NaN       NaN        NaN     NaN            NaN
# 2020-03-05    AK       NaN       NaN        NaN     NaN            NaN
# ...          ...       ...       ...        ...     ...            ...
# 2021-11-07    AK       0.0  141182.0        0.0   723.0       152065.0
# 2021-11-08    AK    1339.0  142521.0       51.0   774.0            NaN
# 2021-11-09    AK     372.0  142893.0       28.0   802.0            NaN
# 2021-11-10    AK     452.0  143345.0        9.0   811.0            NaN
# 2021-11-11    AK       NaN       NaN        NaN     NaN            NaN
#
#             negativeTests  vaccinationsCompleted  hospitalBeds.capacity  \
# date
# ...

# %%
AK = AK[['newCases', 'newDeaths', 'positiveTests','vaccinationsCompleted','mask_mandate', 'daily_infection_rate', 'daily_death_rate',
       'newCases_density', 'newDeaths_density']]

# %%
axs = AK.plot.area(figsize=(20, 15), subplots=True)

# %%
CA = df.loc[df['state']=='CA']
CA = CA[['newCases', 'newDeaths', 'positiveTests','vaccinationsCompleted','mask_mandate', 'daily_infection_rate', 'daily_death_rate',
       'newCases_density', 'newDeaths_density']]

# %%
CA.plot.area(figsize=(20, 15), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>], dtype=object)
